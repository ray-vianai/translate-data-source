# %%
import pandas as pd
import os

# %%
# Check if all items in data folder have corresponding files in out folder
data_folder = './data'
out_folder = './out'
items = os.listdir(data_folder)
missing_items = []
for item in items:
    # Skip folders and .ipynb_checkpoints
    if os.path.isdir(os.path.join(data_folder, item)) or '.ipynb_checkpoints' in item:
        continue
        
    out_file = os.path.join(out_folder, item)
    if not os.path.exists(out_file):
        missing_items.append(item)

if missing_items:
    print(f"Found {len(missing_items)} missing items:")
    for item in missing_items:
        print(f"- {item}")
else:
    print("No missing items found.")
# Out:
# No missing items found.

# %%
# Try to load and compare files
for item in items:
    data_file = os.path.join(data_folder, item)
    out_file = os.path.join(out_folder, item)
    
    print(f"\nComparing {item}:")
    
    # Determine file type and load accordingly
    if item.endswith('.parquet'):
        try:
            data_df = pd.read_parquet(data_file)
            out_df = pd.read_parquet(out_file)
            print("\nData file first 2 rows:")
            print(data_df.head(2))
            print("\nOutput file first 2 rows:")
            print(out_df.head(2))
        except Exception as e:
            print(f"Error loading parquet files: {e}")
            
    elif item.endswith('.json'):
        try:
            data_df = pd.read_json(data_file)
            out_df = pd.read_json(out_file)
            print("\nData file first 2 rows:")
            print(data_df.head(2))
            print("\nOutput file first 2 rows:")
            print(out_df.head(2))
        except Exception as e:
            print(f"Error loading json files: {e}")
            
    else:
        print(f"Unsupported file type for {item}")
# Out:
# Comparing journal_chunk_6.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          IND   2024-08-09        2024           P08          63002
# 1          USA   2024-02-27        2024           P02          65003
#
#   company_currency company_amount global_currency global_amount  \
# 0              INR       83130.61             USD        996.77
# 1              USD         910.51             USD        910.51
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP006  ...         CS08458        P060076        CH00004
# 1             DP007  ...         CS08114        P060076        CH00004
#
#   division_number       transaction_id transaction_type  \
# 0         DV00004  7317919603814998042            TT002
# 1         DV00003  7317919603814998043            TT005
#
#   transaction_document_number transaction_document_item  \
# 0                  240809-655                       020
# 1                  240227-547                       289
#
#   transaction_description reference_procedure
# 0                                       RP004
# 1                                       RP002
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          IND   2024-08-09        2024           P08          63002
# 1          USA   2024-02-27        2024           P02          65003
#
#   company_currency company_amount global_currency global_amount  \
# 0              INR       83130.61             USD        996.77
# 1              USD         910.51             USD        910.51
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP006  ...         CS08458        P060076        CH00004
# 1             DP007  ...         CS08114        P060076        CH00004
#
#   division_number       transaction_id transaction_type  \
# 0         DV00004  7317919603814998042            TT002
# 1         DV00003  7317919603814998043            TT005
#
#   transaction_document_number transaction_document_item  \
# 0                  240809-655                       020
# 1                  240227-547                       289
#
#   transaction_description reference_procedure
# 0                                       RP004
# 1                                       RP002
#
# [2 rows x 27 columns]
#
# Comparing cost_center.parquet:
#
# Data file first 2 rows:
#   cost_center_number       cost_center_name
# 0             CC1001  Manufacturing Plant A
# 1             CC1002  Manufacturing Plant B
#
# Output file first 2 rows:
#   cost_center_number cost_center_name
# 0             CC1001            製造工場A
# 1             CC1002          製造プラントB
#
# Comparing material_group.parquet:
#
# Data file first 2 rows:
#   material_group_number material_group_name
# 0                MG0010            Plastics
# 1                MG0006               Glass
#
# Output file first 2 rows:
#   material_group_number material_group_name
# 0                MG0010              プラスチック
# 1                MG0006                 ガラス
#
# Comparing material.parquet:
#
# Data file first 2 rows:
#   material_number  material_name material_group_number
# 0         M090001   Polyethylene                MG0010
# 1         M090002  Polypropylene                MG0010
#
# Output file first 2 rows:
#   material_number material_name material_group_number
# 0         M090001        ポリエチレン                MG0010
# 1         M090002       ポリプロピレン                MG0010
#
# Comparing journal_chunk_7.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          AUS   2023-11-30        2023           P11          51001
# 1          GBR   2023-11-16        2023           P11          40002
#
#   company_currency company_amount global_currency global_amount  \
# 0              AUD       37694.96             USD      24963.55
# 1              GBP       13581.38             USD      17412.03
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP011  ...         CS08055        P060023        CH00002
# 1             DP012  ...         CS08214        P060082        CH00005
#
#   division_number       transaction_id transaction_type  \
# 0         DV00004  7317919610655907840            TT004
# 1         DV00005  7317919610655907841            TT003
#
#   transaction_document_number transaction_document_item  \
# 0                  231130-116                       080
# 1                  231116-180                       287
#
#   transaction_description reference_procedure
# 0                                       RP004
# 1                                       RP006
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          AUS   2023-11-30        2023           P11          51001
# 1          GBR   2023-11-16        2023           P11          40002
#
#   company_currency company_amount global_currency global_amount  \
# 0              AUD       37694.96             USD      24963.55
# 1              GBP       13581.38             USD      17412.03
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP011  ...         CS08055        P060023        CH00002
# 1             DP012  ...         CS08214        P060082        CH00005
#
#   division_number       transaction_id transaction_type  \
# 0         DV00004  7317919610655907840            TT004
# 1         DV00005  7317919610655907841            TT003
#
#   transaction_document_number transaction_document_item  \
# 0                  231130-116                       080
# 1                  231116-180                       287
#
#   transaction_description reference_procedure
# 0                                       RP004
# 1                                       RP006
#
# [2 rows x 27 columns]
#
# Comparing images:
# Unsupported file type for images
#
# Comparing supplier.parquet:
#
# Data file first 2 rows:
#   supplier_number             supplier_name
# 0         SP03001  Acme Packaging Solutions
# 1         SP03002        GreenLeaf Naturals
#
# Output file first 2 rows:
#   supplier_number       supplier_name
# 0         SP03001  アクメパッケージングソリューションズ
# 1         SP03002       グリーンリーフナチュラルズ
#
# Comparing journal_chunk_15.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          CHN   2023-04-15        2023           P04          62002
# 1          IND   2022-05-31        2022           P05          50001
#
#   company_currency company_amount global_currency global_amount  \
# 0              CNY       14483.32             USD       2006.00
# 1              INR     1470909.12             USD      17636.80
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP014  ...         CS08340        P060080        CH00002
# 1             DP012  ...         CS08480        P060045        CH00005
#
#   division_number       transaction_id transaction_type  \
# 0         DV00006  7317919641442099204            TT005
# 1         DV00002  7317919641442099205            TT003
#
#   transaction_document_number transaction_document_item  \
# 0                  230415-297                       005
# 1                  220531-563                       248
#
#   transaction_description reference_procedure
# 0                                       RP009
# 1                                       RP007
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          CHN   2023-04-15        2023           P04          62002
# 1          IND   2022-05-31        2022           P05          50001
#
#   company_currency company_amount global_currency global_amount  \
# 0              CNY       14483.32             USD       2006.00
# 1              INR     1470909.12             USD      17636.80
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP014  ...         CS08340        P060080        CH00002
# 1             DP012  ...         CS08480        P060045        CH00005
#
#   division_number       transaction_id transaction_type  \
# 0         DV00006  7317919641442099204            TT005
# 1         DV00002  7317919641442099205            TT003
#
#   transaction_document_number transaction_document_item  \
# 0                  230415-297                       005
# 1                  220531-563                       248
#
#   transaction_description reference_procedure
# 0                                       RP009
# 1                                       RP007
#
# [2 rows x 27 columns]
#
# Comparing profit_center.parquet:
#
# Data file first 2 rows:
#   profit_center_number profit_center_name
# 0               PC0001  Beverage Division
# 1               PC0002    Snacks Division
#
# Output file first 2 rows:
#   profit_center_number profit_center_name
# 0               PC0001               飲料部門
# 1               PC0002             スナック部門
#
# Comparing journal_chunk_5.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          AUS   2021-12-09        2021           P12          64005
# 1          FRA   2024-10-17        2024           P10          63002
#
#   company_currency company_amount global_currency global_amount  \
# 0              AUD         139.10             USD         92.12
# 1              EUR         398.33             USD        432.97
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP015  ...         CS08002        P060047        CH00001
# 1             DP015  ...         CS08111        P060100        CH00001
#
#   division_number       transaction_id transaction_type  \
# 0         DV00003  7317919597750034433            TT002
# 1         DV00004  7317919597750034434            TT003
#
#   transaction_document_number transaction_document_item  \
# 0                  211209-727                       127
# 1                  241017-123                       208
#
#   transaction_description reference_procedure
# 0                                       RP003
# 1                                       RP001
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          AUS   2021-12-09        2021           P12          64005
# 1          FRA   2024-10-17        2024           P10          63002
#
#   company_currency company_amount global_currency global_amount  \
# 0              AUD         139.10             USD         92.12
# 1              EUR         398.33             USD        432.97
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP015  ...         CS08002        P060047        CH00001
# 1             DP015  ...         CS08111        P060100        CH00001
#
#   division_number       transaction_id transaction_type  \
# 0         DV00003  7317919597750034433            TT002
# 1         DV00004  7317919597750034434            TT003
#
#   transaction_document_number transaction_document_item  \
# 0                  211209-727                       127
# 1                  241017-123                       208
#
#   transaction_description reference_procedure
# 0                                       RP003
# 1                                       RP001
#
# [2 rows x 27 columns]
#
# Comparing journal_chunk_4.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          USA   2022-05-12        2022           P05          75003
# 1          FRA   2024-04-05        2024           P04          60002
#
#   company_currency company_amount global_currency global_amount  \
# 0              USD        5510.06             USD       5510.06
# 1              EUR         337.41             USD        366.75
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP014  ...         CS08313        P060014        CH00002
# 1             DP012  ...         CS08094        P060085        CH00002
#
#   division_number       transaction_id transaction_type  \
# 0         DV00004  7317919591504715776            TT002
# 1         DV00002  7317919591504715777            TT004
#
#   transaction_document_number transaction_document_item  \
# 0                  220512-735                       232
# 1                  240405-715                       280
#
#   transaction_description reference_procedure
# 0                                       RP006
# 1                                       RP005
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          USA   2022-05-12        2022           P05          75003
# 1          FRA   2024-04-05        2024           P04          60002
#
#   company_currency company_amount global_currency global_amount  \
# 0              USD        5510.06             USD       5510.06
# 1              EUR         337.41             USD        366.75
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP014  ...         CS08313        P060014        CH00002
# 1             DP012  ...         CS08094        P060085        CH00002
#
#   division_number       transaction_id transaction_type  \
# 0         DV00004  7317919591504715776            TT002
# 1         DV00002  7317919591504715777            TT004
#
#   transaction_document_number transaction_document_item  \
# 0                  220512-735                       232
# 1                  240405-715                       280
#
#   transaction_description reference_procedure
# 0                                       RP006
# 1                                       RP005
#
# [2 rows x 27 columns]
#
# Comparing division.parquet:
#
# Data file first 2 rows:
#   division_number division_name
# 0         DV00001     Marketing
# 1         DV00002         Sales
#
# Output file first 2 rows:
#   division_number division_name
# 0         DV00001       マーケティング
# 1         DV00002            販売
#
# Comparing channel.parquet:
#
# Data file first 2 rows:
#   channel_number              channel_name
# 0        CH00001  Direct-to-Consumer (DTC)
# 1        CH00002   Brick-and-Mortar Retail
#
# Output file first 2 rows:
#   channel_number   channel_name
# 0        CH00001  直接消費者向け (DTC)
# 1        CH00002         従来型小売店
#
# Comparing journal_chunk_14.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          IND   2023-01-24        2023           P01          64001
# 1          USA   2022-12-06        2022           P12          75004
#
#   company_currency company_amount global_currency global_amount  \
# 0              INR       86209.74             USD       1033.69
# 1              USD        1481.65             USD       1481.65
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP013  ...         CS08196        P060033        CH00002
# 1             DP003  ...         CS08189        P060065        CH00004
#
#   division_number       transaction_id transaction_type  \
# 0         DV00006  7317919634882207747            TT004
# 1         DV00002  7317919634882207748            TT004
#
#   transaction_document_number transaction_document_item  \
# 0                  230124-392                       170
# 1                  221206-177                       070
#
#   transaction_description reference_procedure
# 0                                       RP001
# 1                                       RP001
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          IND   2023-01-24        2023           P01          64001
# 1          USA   2022-12-06        2022           P12          75004
#
#   company_currency company_amount global_currency global_amount  \
# 0              INR       86209.74             USD       1033.69
# 1              USD        1481.65             USD       1481.65
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP013  ...         CS08196        P060033        CH00002
# 1             DP003  ...         CS08189        P060065        CH00004
#
#   division_number       transaction_id transaction_type  \
# 0         DV00006  7317919634882207747            TT004
# 1         DV00002  7317919634882207748            TT004
#
#   transaction_document_number transaction_document_item  \
# 0                  230124-392                       170
# 1                  221206-177                       070
#
#   transaction_description reference_procedure
# 0                                       RP001
# 1                                       RP001
#
# [2 rows x 27 columns]
#
# Comparing fiscal_period.parquet:
#
# Data file first 2 rows:
#   fiscal_year fiscal_period fiscal_month fiscal_quarter
# 0        2018           P01          M01             Q1
# 1        2018           P02          M02             Q1
#
# Output file first 2 rows:
#   fiscal_year fiscal_period fiscal_month fiscal_quarter
# 0        2018           P01          M01             Q1
# 1        2018           P02          M02             Q1
#
# Comparing config.parquet:
#
# Data file first 2 rows:
#              config_key config_value
# 0  latest_closed_period     2025-P02
#
# Output file first 2 rows:
#              config_key config_value
# 0  latest_closed_period     2025-P02
#
# Comparing journal_chunk_8.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          USA   2023-09-15        2023           P09          64005
# 1          JPN   2021-01-22        2021           P01          75001
#
#   company_currency company_amount global_currency global_amount  \
# 0              USD         534.34             USD        534.34
# 1              JPY     1825810.06             USD      11854.37
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP001  ...         CS08368        P060076        CH00003
# 1             DP014  ...         CS08472        P060021        CH00001
#
#   division_number       transaction_id transaction_type  \
# 0         DV00002  7317919615777153039            TT005
# 1         DV00001  7317919615777153040            TT001
#
#   transaction_document_number transaction_document_item  \
# 0                  230915-053                       005
# 1                  210122-542                       220
#
#   transaction_description reference_procedure
# 0                                       RP010
# 1                                       RP006
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          USA   2023-09-15        2023           P09          64005
# 1          JPN   2021-01-22        2021           P01          75001
#
#   company_currency company_amount global_currency global_amount  \
# 0              USD         534.34             USD        534.34
# 1              JPY     1825810.06             USD      11854.37
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP001  ...         CS08368        P060076        CH00003
# 1             DP014  ...         CS08472        P060021        CH00001
#
#   division_number       transaction_id transaction_type  \
# 0         DV00002  7317919615777153039            TT005
# 1         DV00001  7317919615777153040            TT001
#
#   transaction_document_number transaction_document_item  \
# 0                  230915-053                       005
# 1                  210122-542                       220
#
#   transaction_description reference_procedure
# 0                                       RP010
# 1                                       RP006
#
# [2 rows x 27 columns]
#
# Comparing journal_chunk_11.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          FRA   2021-06-12        2021           P06          51004
# 1          JPN   2021-03-31        2021           P03          50002
#
#   company_currency company_amount global_currency global_amount  \
# 0              EUR         137.28             USD        149.22
# 1              JPY      360141.88             USD       2338.28
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP008  ...         CS08151        P060003        CH00002
# 1             DP014  ...         CS08418        P060075        CH00004
#
#   division_number       transaction_id transaction_type  \
# 0         DV00004  7317919624450973714            TT004
# 1         DV00005  7317919624450973715            TT001
#
#   transaction_document_number transaction_document_item  \
# 0                  210612-768                       230
# 1                  210331-015                       188
#
#   transaction_description reference_procedure
# 0                                       RP005
# 1                                       RP002
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          FRA   2021-06-12        2021           P06          51004
# 1          JPN   2021-03-31        2021           P03          50002
#
#   company_currency company_amount global_currency global_amount  \
# 0              EUR         137.28             USD        149.22
# 1              JPY      360141.88             USD       2338.28
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP008  ...         CS08151        P060003        CH00002
# 1             DP014  ...         CS08418        P060075        CH00004
#
#   division_number       transaction_id transaction_type  \
# 0         DV00004  7317919624450973714            TT004
# 1         DV00005  7317919624450973715            TT001
#
#   transaction_document_number transaction_document_item  \
# 0                  210612-768                       230
# 1                  210331-015                       188
#
#   transaction_description reference_procedure
# 0                                       RP005
# 1                                       RP002
#
# [2 rows x 27 columns]
#
# Comparing account.parquet:
#
# Data file first 2 rows:
#   account_number                        account_name account_type_code  \
# 0          40001           Sales Revenue - Wholesale               REV
# 1          40002  Sales Revenue - Direct to Consumer               REV
#
#   account_type account_subtype_code account_subtype account_category
# 0      Revenue                  INC          Income    Sales Revenue
# 1      Revenue                  INC          Income    Sales Revenue
#
# Output file first 2 rows:
#   account_number    account_name account_type_code account_type  \
# 0          40001       販売収益 - 卸売               REV           収益
# 1          40002  売上収益 - 直接消費者向け               REV           収益
#
#   account_subtype_code account_subtype account_category
# 0                  INC              収入              売上高
# 1                  INC              収入              売上高
#
# Comparing journal_chunk_1.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          BRA   2025-03-23        2025           P03          40003
# 1          CHN   2022-12-16        2022           P12          61005
#
#   company_currency company_amount global_currency global_amount  \
# 0              BRL      100006.30             USD      19048.82
# 1              CNY        7720.34             USD       1069.30
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP006  ...         CS08020        P060045        CH00002
# 1             DP004  ...         CS08370        P060057        CH00002
#
#   division_number       transaction_id transaction_type  \
# 0         DV00002  7317919591018176512            TT002
# 1         DV00001  7317919591085285376            TT002
#
#   transaction_document_number transaction_document_item  \
# 0                  250323-713                       132
# 1                  221216-048                       223
#
#   transaction_description reference_procedure
# 0                                       RP003
# 1                                       RP009
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          BRA   2025-03-23        2025           P03          40003
# 1          CHN   2022-12-16        2022           P12          61005
#
#   company_currency company_amount global_currency global_amount  \
# 0              BRL      100006.30             USD      19048.82
# 1              CNY        7720.34             USD       1069.30
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP006  ...         CS08020        P060045        CH00002
# 1             DP004  ...         CS08370        P060057        CH00002
#
#   division_number       transaction_id transaction_type  \
# 0         DV00002  7317919591018176512            TT002
# 1         DV00001  7317919591085285376            TT002
#
#   transaction_document_number transaction_document_item  \
# 0                  250323-713                       132
# 1                  221216-048                       223
#
#   transaction_description reference_procedure
# 0                                       RP003
# 1                                       RP009
#
# [2 rows x 27 columns]
#
# Comparing department.parquet:
#
# Data file first 2 rows:
#   department_number           department_name
# 0             DP001  Research and Development
# 1             DP002        Product Management
#
# Output file first 2 rows:
#   department_number department_name
# 0             DP001            研究開発
# 1             DP002     プロダクトマネジメント
#
# Comparing product.parquet:
#
# Data file first 2 rows:
#   product_number          product_name product_group_number
# 0        P060001   Organic Almond Milk               PG0008
# 1        P060002  Unsweetened Soy Milk               PG0008
#
# Output file first 2 rows:
#   product_number    product_name product_group_number
# 0        P060001  オーガニックアーモンドミルク               PG0008
# 1        P060002           無糖の豆乳               PG0008
#
# Comparing journal_chunk_9.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          JPN   2022-11-07        2022           P11          51001
# 1          JPN   2024-03-22        2024           P03          75001
#
#   company_currency company_amount global_currency global_amount  \
# 0              JPY      332110.24             USD       2156.28
# 1              JPY     5909202.16             USD      38366.46
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP010  ...         CS08354        P060018        CH00002
# 1             DP006  ...         CS08465        P060002        CH00005
#
#   division_number       transaction_id transaction_type  \
# 0         DV00001  7317919621716287488            TT001
# 1         DV00005  7317919621716287489            TT003
#
#   transaction_document_number transaction_document_item  \
# 0                  221107-791                       007
# 1                  240322-382                       036
#
#   transaction_description reference_procedure
# 0                                       RP007
# 1                                       RP010
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          JPN   2022-11-07        2022           P11          51001
# 1          JPN   2024-03-22        2024           P03          75001
#
#   company_currency company_amount global_currency global_amount  \
# 0              JPY      332110.24             USD       2156.28
# 1              JPY     5909202.16             USD      38366.46
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP010  ...         CS08354        P060018        CH00002
# 1             DP006  ...         CS08465        P060002        CH00005
#
#   division_number       transaction_id transaction_type  \
# 0         DV00001  7317919621716287488            TT001
# 1         DV00005  7317919621716287489            TT003
#
#   transaction_document_number transaction_document_item  \
# 0                  221107-791                       007
# 1                  240322-382                       036
#
#   transaction_description reference_procedure
# 0                                       RP007
# 1                                       RP010
#
# [2 rows x 27 columns]
#
# Comparing journal_chunk_10.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          DEU   2024-04-21        2024           P04          51003
# 1          USA   2021-10-01        2021           P10          40003
#
#   company_currency company_amount global_currency global_amount  \
# 0              EUR         280.29             USD        304.67
# 1              USD       15882.96             USD      15882.96
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP015  ...         CS08400        P060086        CH00001
# 1             DP004  ...         CS08091        P060040        CH00001
#
#   division_number       transaction_id transaction_type  \
# 0         DV00001  7317919618549587968            TT003
# 1         DV00005  7317919618549587969            TT003
#
#   transaction_document_number transaction_document_item  \
# 0                  240421-789                       053
# 1                  211001-584                       125
#
#   transaction_description reference_procedure
# 0                                       RP004
# 1                                       RP001
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          DEU   2024-04-21        2024           P04          51003
# 1          USA   2021-10-01        2021           P10          40003
#
#   company_currency company_amount global_currency global_amount  \
# 0              EUR         280.29             USD        304.67
# 1              USD       15882.96             USD      15882.96
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP015  ...         CS08400        P060086        CH00001
# 1             DP004  ...         CS08091        P060040        CH00001
#
#   division_number       transaction_id transaction_type  \
# 0         DV00001  7317919618549587968            TT003
# 1         DV00005  7317919618549587969            TT003
#
#   transaction_document_number transaction_document_item  \
# 0                  240421-789                       053
# 1                  211001-584                       125
#
#   transaction_description reference_procedure
# 0                                       RP004
# 1                                       RP001
#
# [2 rows x 27 columns]
#
# Comparing .ipynb_checkpoints:
# Unsupported file type for .ipynb_checkpoints
#
# Comparing journal_chunk_2.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          FRA   2022-09-09        2022           P09          50002
# 1          BRA   2023-08-21        2023           P08          51004
#
#   company_currency company_amount global_currency global_amount  \
# 0              EUR        4745.45             USD       5158.10
# 1              BRL         172.77             USD         32.91
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP013  ...         CS08357        P060030        CH00005
# 1             DP008  ...         CS08474        P060026        CH00002
#
#   division_number       transaction_id transaction_type  \
# 0         DV00005  7317919597087334423            TT004
# 1         DV00002  7317919597087334424            TT005
#
#   transaction_document_number transaction_document_item  \
# 0                  220909-090                       096
# 1                  230821-385                       068
#
#   transaction_description reference_procedure
# 0                                       RP001
# 1                                       RP007
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          FRA   2022-09-09        2022           P09          50002
# 1          BRA   2023-08-21        2023           P08          51004
#
#   company_currency company_amount global_currency global_amount  \
# 0              EUR        4745.45             USD       5158.10
# 1              BRL         172.77             USD         32.91
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP013  ...         CS08357        P060030        CH00005
# 1             DP008  ...         CS08474        P060026        CH00002
#
#   division_number       transaction_id transaction_type  \
# 0         DV00005  7317919597087334423            TT004
# 1         DV00002  7317919597087334424            TT005
#
#   transaction_document_number transaction_document_item  \
# 0                  220909-090                       096
# 1                  230821-385                       068
#
#   transaction_description reference_procedure
# 0                                       RP001
# 1                                       RP007
#
# [2 rows x 27 columns]
#
# Comparing journal_chunk_12.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          DEU   2021-07-13        2021           P07          65003
# 1          IND   2021-10-11        2021           P10          60003
#
#   company_currency company_amount global_currency global_amount  \
# 0              EUR          99.74             USD        108.42
# 1              INR       23574.67             USD        282.67
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP001  ...         CS08162        P060006        CH00004
# 1             DP008  ...         CS08217        P060005        CH00001
#
#   division_number       transaction_id transaction_type  \
# 0         DV00002  7317919631564513300            TT004
# 1         DV00001  7317919631564513301            TT003
#
#   transaction_document_number transaction_document_item  \
# 0                  210713-680                       054
# 1                  211011-324                       204
#
#   transaction_description reference_procedure
# 0                                       RP005
# 1                                       RP002
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          DEU   2021-07-13        2021           P07          65003
# 1          IND   2021-10-11        2021           P10          60003
#
#   company_currency company_amount global_currency global_amount  \
# 0              EUR          99.74             USD        108.42
# 1              INR       23574.67             USD        282.67
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP001  ...         CS08162        P060006        CH00004
# 1             DP008  ...         CS08217        P060005        CH00001
#
#   division_number       transaction_id transaction_type  \
# 0         DV00002  7317919631564513300            TT004
# 1         DV00001  7317919631564513301            TT003
#
#   transaction_document_number transaction_document_item  \
# 0                  210713-680                       054
# 1                  211011-324                       204
#
#   transaction_description reference_procedure
# 0                                       RP005
# 1                                       RP002
#
# [2 rows x 27 columns]
#
# Comparing company.parquet:
#
# Data file first 2 rows:
#   company_code                 company_name company_country company_region  \
# 0          AUS  EverGreen Australia Pty Ltd       Australia        Oceania
# 1          NZL    EverGreen New Zealand Ltd     New Zealand        Oceania
#
#   currency_code language_code
# 0           AUD            en
# 1           NZD            en
#
# Output file first 2 rows:
#   company_code          company_name company_country company_region  \
# 0          AUS    エバーグリーンオーストラリア株式会社         オーストラリア          オセアニア
# 1          NZL  エバーグリーン ニュージーランド株式会社        ニュージーランド          オセアニア
#
#   currency_code language_code
# 0           AUD            en
# 1           NZD            en
#
# Comparing product_group.parquet:
#
# Data file first 2 rows:
#   product_group_number  product_group_name
# 0               PG0008  Dairy Alternatives
# 1               PG0013      Nuts & Spreads
#
# Output file first 2 rows:
#   product_group_number product_group_name
# 0               PG0008            乳製品の代替品
# 1               PG0013          ナッツとスプレッド
#
# Comparing journal_chunk_13.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          IND   2023-10-11        2023           P10          60003
# 1          IND   2023-06-18        2023           P06          61002
#
#   company_currency company_amount global_currency global_amount  \
# 0              INR        7769.54             USD         93.16
# 1              INR       44237.86             USD        530.43
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP010  ...         CS08445        P060073        CH00004
# 1             DP007  ...         CS08132        P060050        CH00004
#
#   division_number       transaction_id transaction_type  \
# 0         DV00002  7317919627999354880            TT002
# 1         DV00004  7317919627999354881            TT001
#
#   transaction_document_number transaction_document_item  \
# 0                  231011-119                       206
# 1                  230618-064                       255
#
#   transaction_description reference_procedure
# 0                                       RP008
# 1                                       RP006
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          IND   2023-10-11        2023           P10          60003
# 1          IND   2023-06-18        2023           P06          61002
#
#   company_currency company_amount global_currency global_amount  \
# 0              INR        7769.54             USD         93.16
# 1              INR       44237.86             USD        530.43
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP010  ...         CS08445        P060073        CH00004
# 1             DP007  ...         CS08132        P060050        CH00004
#
#   division_number       transaction_id transaction_type  \
# 0         DV00002  7317919627999354880            TT002
# 1         DV00004  7317919627999354881            TT001
#
#   transaction_document_number transaction_document_item  \
# 0                  231011-119                       206
# 1                  230618-064                       255
#
#   transaction_description reference_procedure
# 0                                       RP008
# 1                                       RP006
#
# [2 rows x 27 columns]
#
# Comparing fiscal_calendar.parquet:
#
# Data file first 2 rows:
#   posting_date fiscal_year fiscal_period fiscal_month fiscal_quarter
# 0   2018-01-01        2018           P01          M01             Q1
# 1   2018-01-02        2018           P01          M01             Q1
#
# Output file first 2 rows:
#   posting_date fiscal_year fiscal_period fiscal_month fiscal_quarter
# 0   2018-01-01        2018           P01          M01             Q1
# 1   2018-01-02        2018           P01          M01             Q1
#
# Comparing company_config.json:
#
# Data file first 2 rows:
#                                              AUS                       BRA  \
# parent_company_name            EverGreen Pvt Ltd         EverGreen Pvt Ltd
# company_name         EverGreen Australia Pty Ltd  EverGreen do Brasil Ltda
#
#                                           CHN                         DEU  \
# parent_company_name         EverGreen Pvt Ltd           EverGreen Pvt Ltd
# company_name         EverGreen China Co. Ltd.  EverGreen Deutschland GmbH
#
#                                        FRA                GBR  \
# parent_company_name      EverGreen Pvt Ltd  EverGreen Pvt Ltd
# company_name         EverGreen France S.A.   EverGreen UK Ltd
#
#                                          IND                   JPN  \
# parent_company_name        EverGreen Pvt Ltd     EverGreen Pvt Ltd
# company_name         EverGreen India Pvt Ltd  EverGreen Japan K.K.
#
#                                            NZL                 USA
# parent_company_name          EverGreen Pvt Ltd   EverGreen Pvt Ltd
# company_name         EverGreen New Zealand Ltd  EverGreen USA Inc.
#
# Output file first 2 rows:
#                                     AUS              BRA            CHN  \
# parent_company_name         エバーグリーン株式会社      エバーグリーン株式会社    エバーグリーン株式会社
# company_name         エバーグリーンオーストラリア株式会社  エバーグリーン・ド・ブラジル社  エバーグリーン中国株式会社
#
#                                      DEU                FRA            GBR  \
# parent_company_name          エバーグリーン株式会社        エバーグリーン株式会社    エバーグリーン株式会社
# company_name         エバーグリーン・ドイチュラント株式会社  エバーグリーン フランス S.A.  エバーグリーンUK Ltd
#
#                                             IND              JPN  \
# parent_company_name                 エバーグリーン株式会社      エバーグリーン株式会社
# company_name         エバーグリーン インディア プライベート リミテッド  エバーグリーンジャパン株式会社
#
#                                       NZL             USA
# parent_company_name           エバーグリーン株式会社     エバーグリーン株式会社
# company_name         エバーグリーン ニュージーランド株式会社  エバーグリーンUSA株式会社
#
# Comparing customer.parquet:
#
# Data file first 2 rows:
#   customer_number   customer_name
# 0         CS08001  Acme Retailers
# 1         CS08002      BrightMart
#
# Output file first 2 rows:
#   customer_number customer_name
# 0         CS08001       アクメ小売業者
# 1         CS08002       ブライトマート
#
# Comparing journal_chunk_3.parquet:
#
# Data file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          BRA   2023-04-22        2023           P04          61003
# 1          NZL   2022-09-13        2022           P09          75002
#
#   company_currency company_amount global_currency global_amount  \
# 0              BRL        2298.34             USD        437.78
# 1              NZD         984.60             USD        596.73
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP013  ...         CS08480        P060083        CH00003
# 1             DP003  ...         CS08149        P060043        CH00003
#
#   division_number       transaction_id transaction_type  \
# 0         DV00006  7317919602950971423            TT001
# 1         DV00001  7317919602950971424            TT005
#
#   transaction_document_number transaction_document_item  \
# 0                  230422-794                       104
# 1                  220913-752                       070
#
#   transaction_description reference_procedure
# 0                                       RP007
# 1                                       RP007
#
# [2 rows x 27 columns]
#
# Output file first 2 rows:
#   company_code posting_date fiscal_year fiscal_period account_number  \
# 0          BRA   2023-04-22        2023           P04          61003
# 1          NZL   2022-09-13        2022           P09          75002
#
#   company_currency company_amount global_currency global_amount  \
# 0              BRL        2298.34             USD        437.78
# 1              NZD         984.60             USD        596.73
#
#   department_number  ... customer_number product_number channel_number  \
# 0             DP013  ...         CS08480        P060083        CH00003
# 1             DP003  ...         CS08149        P060043        CH00003
#
#   division_number       transaction_id transaction_type  \
# 0         DV00006  7317919602950971423            TT001
# 1         DV00001  7317919602950971424            TT005
#
#   transaction_document_number transaction_document_item  \
# 0                  230422-794                       104
# 1                  220913-752                       070
#
#   transaction_description reference_procedure
# 0                                       RP007
# 1                                       RP007
#
# [2 rows x 27 columns]
#
# Comparing plan.parquet:
#
# Data file first 2 rows:
#   company_code fiscal_year fiscal_period profit_center_number product_number  \
# 0          AUS        2021           P01               PC0001        P060001
# 1          AUS        2021           P01               PC0001        P060002
#
#   company_currency company_actual_amount company_budget_amount  \
# 0              AUD                  0.00               9727.97
# 1              AUD                  0.00              14379.47
#
#   company_forecast_amount company_previous_forecast_amount global_currency  \
# 0                    0.00                             0.00             USD
# 1                    0.00                             0.00             USD
#
#   global_actual_amount global_budget_amount global_forecast_amount  \
# 0                 0.00              6442.37                   0.00
# 1                 0.00              9522.83                   0.00
#
#   global_previous_forecast_amount
# 0                            0.00
# 1                            0.00
#
# Output file first 2 rows:
#   company_code fiscal_year fiscal_period profit_center_number product_number  \
# 0          AUS        2021           P01               PC0001        P060001
# 1          AUS        2021           P01               PC0001        P060002
#
#   company_currency company_actual_amount company_budget_amount  \
# 0              AUD                  0.00               9727.97
# 1              AUD                  0.00              14379.47
#
#   company_forecast_amount company_previous_forecast_amount global_currency  \
# 0                    0.00                             0.00             USD
# 1                    0.00                             0.00             USD
#
#   global_actual_amount global_budget_amount global_forecast_amount  \
# 0                 0.00              6442.37                   0.00
# 1                 0.00              9522.83                   0.00
#
#   global_previous_forecast_amount
# 0                            0.00
# 1                            0.00
